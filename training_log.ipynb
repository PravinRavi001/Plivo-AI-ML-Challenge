# %%
# !git clone https://github.com/PravinRavi001/Plivo-AI-ML-Challenge.git
# Out:
# Cloning into 'Plivo-AI-ML-Challenge'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 61 (delta 9), reused 0 (delta 0), pack-reused 40 (from 1)
# Receiving objects: 100% (61/61), 79.85 MiB | 25.03 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %cd Plivo-AI-ML-Challenge
# Out:
# /content/Plivo-AI-ML-Challenge

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=2a59968da96d10815004b48ff17450dd5a5e49e1f8b90d57b8a7992218eeb434
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %% [markdown]
# ## Training Log

# %% [markdown]
# ### DistilBert Baseline

# %%
# !python src/train.py \
--model_name distilbert-base-uncased \
--train data/train_gen.jsonl \
--dev data/dev_gen.jsonl \
--out_dir out
# Out:
# 2025-11-23 19:19:30.679041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763925570.698345    1478 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763925570.704212    1478 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763925570.720278    1478 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/predict.py --model_dir out --input data/dev_gen.jsonl --output out/dev_pred.json
# Out:
# 2025-11-23 19:19:59.676653: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763925599.696468    1621 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763925599.702394    1621 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763925599.716962    1621 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/eval_span_f1.py --gold data/dev_gen.jsonl --pred out/dev_pred.json
# Out:
# Per-entity metrics:
# CITY            P=1.000 R=1.000 F1=1.000
# CREDIT_CARD     P=0.625 R=0.625 F1=0.625
# DATE            P=1.000 R=1.000 F1=1.000
# EMAIL           P=1.000 R=1.000 F1=1.000
# LOCATION        P=1.000 R=1.000 F1=1.000
# PERSON_NAME     P=1.000 R=1.000 F1=1.000
# PHONE           P=0.900 R=0.900 F1=0.900
#
# Macro-F1: 0.932
#
# PII-only metrics: P=0.933 R=0.933 F1=0.933
# Non-PII metrics: P=1.000 R=1.000 F1=1.000

# %%
# !python src/measure_latency.py --device cpu
# Out:
# 2025-11-23 19:21:32.141544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763925692.161983    2037 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763925692.168747    2037 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763925692.184569    2037 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ### albert-base-v2

# %%
# !python src/train.py \
  --model_name albert-base-v2 \
  --train data/train_gen.jsonl \
  --dev data/dev_gen.jsonl \
  --out_dir out \
  --epochs 5 \
  --lr 2e-5
# Out:
# 2025-11-23 19:25:58.569117: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763925958.588193    3204 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763925958.594094    3204 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763925958.609122    3204 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/predict.py --model_dir out --input data/dev_gen.jsonl --output out/dev_pred.json
# Out:
# 2025-11-23 19:26:41.418431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763926001.437618    3403 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763926001.443554    3403 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763926001.458185    3403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/eval_span_f1.py --gold data/dev_gen.jsonl --pred out/dev_pred.json
# Out:
# Per-entity metrics:
# CITY            P=1.000 R=1.000 F1=1.000
# CREDIT_CARD     P=0.556 R=0.625 F1=0.588
# DATE            P=1.000 R=1.000 F1=1.000
# EMAIL           P=0.933 R=1.000 F1=0.966
# LOCATION        P=0.929 R=1.000 F1=0.963
# PERSON_NAME     P=0.966 R=1.000 F1=0.982
# PHONE           P=0.600 R=0.900 F1=0.720
#
# Macro-F1: 0.888
#
# PII-only metrics: P=0.778 R=0.933 F1=0.848
# Non-PII metrics: P=0.963 R=1.000 F1=0.981

# %%
# !python src/measure_latency.py --device cpu
# Out:
# 2025-11-23 19:27:02.518686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763926022.538201    3508 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763926022.544171    3508 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763926022.559665    3508 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ### microsoft/xtremedistil-l6-h384-uncased

# %%
# !python src/train.py\
 --model_name microsoft/xtremedistil-l6-h384-uncased \
 --train data/train_gen.jsonl \
 --dev data/dev_gen.jsonl \
 --out_dir out \
 --epochs 5 \
 --lr 5e-4
# Out:
# 2025-11-23 19:29:07.905501: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763926147.924444    4056 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763926147.930250    4056 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763926147.944636    4056 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/predict.py --model_dir out --input data/dev_gen.jsonl --output out/dev_pred.json
# Out:
# 2025-11-23 19:29:50.225350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763926190.244387    4281 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763926190.250378    4281 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763926190.264920    4281 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/eval_span_f1.py --gold data/dev_gen.jsonl --pred out/dev_pred.json
# Out:
# Per-entity metrics:
# CITY            P=1.000 R=1.000 F1=1.000
# CREDIT_CARD     P=0.625 R=0.625 F1=0.625
# DATE            P=1.000 R=1.000 F1=1.000
# EMAIL           P=1.000 R=1.000 F1=1.000
# LOCATION        P=1.000 R=1.000 F1=1.000
# PERSON_NAME     P=1.000 R=1.000 F1=1.000
# PHONE           P=0.900 R=0.900 F1=0.900
#
# Macro-F1: 0.932
#
# PII-only metrics: P=0.933 R=0.933 F1=0.933
# Non-PII metrics: P=1.000 R=1.000 F1=1.000

# %%
# !python src/measure_latency.py --device cpu
# Out:
# 2025-11-23 19:30:06.188539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763926206.207582    4364 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763926206.213543    4364 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763926206.228052    4364 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
