# %% [markdown]
# <a href="https://colab.research.google.com/github/PravinRavi001/Plivo-AI-ML-Challenge/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Training Log

# %%
# !python src/train.py \
--model_name distilbert-base-uncased \
--train data/train.jsonl \
--dev data/dev.jsonl \
--out_dir out
# Out:
# python3: can't open file '/content/src/train.py': [Errno 2] No such file or directory
